# %% [markdown]
# # MixMatch implementation
# Unofficial pytorch implementation of MixMatch [[paper]](https://arxiv.org/pdf/1905.02249.pdf) on CIFAR-10.
#
# ## Initialisation

# %%
import numpy as np
import os.path as osp
import torch

from metric_utils.metrics import Metrics

from mlu.utils.misc import reset_seed, get_datetime

from mlu.datasets.wrappers import NoLabelDataset, OneHotDataset, ZipDataset
from mlu.datasets.utils import split_dataset
from mlu.metrics import CategoricalAccuracy
from mlu.nn import CrossEntropyWithVectors
from mlu.utils.printers import ColumnPrinter
from mlu.utils.zip_cycle import ZipCycle

from sslh.models.wideresnet28 import WideResNet28
from sslh.mixmatch.warmup import WarmUp
from sslh.utils.torch import collapse_first_dimension

from torch import Tensor
from torch.optim import Adam
from torch.utils.data.dataloader import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import CIFAR10
from torchvision.transforms import RandomHorizontalFlip, RandomChoice, Compose, ToTensor, Normalize, RandomCrop
from typing import Dict

# %%
reset_seed(1234)

lambda_u = 1.0
temperature = 0.5
alpha = 0.75
nb_epochs = 200
nb_augms = 2  # "K" in paper
lr = 1e-3

dataset_root = osp.join("..", "datasets")
tensorboard_root = osp.join("..", "results", "tensorboard")

device = torch.device("cuda")

# Same as CrossEntropy but accept non-"onehot encoding" vectors as targets (labels)
criterion_s = CrossEntropyWithVectors()
criterion_u = CrossEntropyWithVectors()

# %%
# Build WideResNet-28-2 model
model = WideResNet28(num_classes=10, width=2).to(device)
activation = torch.softmax
optim = Adam(model.parameters(), lr=lr)

# Build metrics. You can add a metric in this dictionary.
metrics_train_s = {"acc_s_mix": CategoricalAccuracy(dim=1)}
metrics_train_u = {"acc_u_mix": CategoricalAccuracy(dim=1)}
metrics_val = {"acc": CategoricalAccuracy(dim=1)}

# Tensorboard writer
writer = SummaryWriter(osp.join(tensorboard_root, "CIFAR10_%s_WideResNet28_MixMatch_Notebook" % get_datetime()))

# Class for managing how the values are print in terminal
printer = ColumnPrinter()

# Linearly increase a value from 0 to lambda_u during 16000 steps.
warmup = WarmUp(nb_steps=16000, max_value=lambda_u)

# %%
def get_loaders() -> (DataLoader, DataLoader):
	augm_weak = RandomChoice([
		RandomHorizontalFlip(0.5),
		RandomCrop((32, 32), padding=8),
	])
	# Add postprocessing after each augmentation (shape : [32, 32, 3] -> [3, 32, 32])
	post_process_fn = Compose([
		ToTensor(),
		Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
	])

	transform_augm_weak = Compose([
		augm_weak,
		post_process_fn,
	])

	# Create train dataloader
	dataset_train_augm_weak = CIFAR10(dataset_root, train=True, download=True, transform=transform_augm_weak)

	# Use 4000 data with labels (8%) and 46000 data without labels (92%)
	dataset_train_s_augm_weak, dataset_train_u_augm_weak = \
		split_dataset(dataset_train_augm_weak, nb_classes=10, ratios=[0.08, 0.92], target_one_hot=False)

	dataset_train_s_augm_weak = OneHotDataset(dataset_train_s_augm_weak, nb_classes=10)
	dataset_train_u_augm_weak = NoLabelDataset(dataset_train_u_augm_weak)

	# Duplicate augmentations calls
	dataset_train_u_augm_weaks = ZipDataset([dataset_train_u_augm_weak] * nb_augms)

	# Build loaders for supervised data and unsupervised data
	loader_train_s_augm = DataLoader(
		dataset=dataset_train_s_augm_weak, batch_size=64, shuffle=True, num_workers=2, drop_last=True)
	loader_train_u_augms = DataLoader(
		dataset=dataset_train_u_augm_weaks, batch_size=64, shuffle=True, num_workers=6, drop_last=True)

	loader_train = ZipCycle([loader_train_s_augm, loader_train_u_augms])

	# Create validation dataloader
	dataset_val = CIFAR10(dataset_root, train=False, download=True, transform=post_process_fn)
	dataset_val = OneHotDataset(dataset_val, nb_classes=10)

	loader_val = DataLoader(dataset=dataset_val, batch_size=64, shuffle=False, drop_last=False)
	return loader_train, loader_val

loader_train, loader_val = get_loaders()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Prepare functions for training

# %%
def criterion(pred_s: Tensor, pred_u: Tensor, labels_s: Tensor, labels_u: Tensor, lambda_u: float) -> (Tensor, Tensor, Tensor):
	loss_s = criterion_s(pred_s, labels_s).mean()
	loss_u = criterion_u(pred_u, labels_u).mean()
	loss = loss_s + lambda_u * loss_u
	return loss, loss_s, loss_u

# %%
def guess_label(batch_u_multiple: Tensor, temperature: float, dim: int) -> Tensor:
	nb_augms = batch_u_multiple.shape[0]
	preds_u = [torch.zeros(0) for _ in range(nb_augms)]
	for k in range(nb_augms):
		logits_u = model(batch_u_multiple[k])
		preds_u[k] = activation(logits_u, dim=dim)
	preds_u = torch.stack(preds_u)
	labels_u = preds_u.mean(dim=0)

	labels_u = sharpen(labels_u, temperature, dim=1)
	return labels_u

# %%
def sharpen(pred: Tensor, temperature: float, dim: int = 1) -> Tensor:
	pred = pred ** (1.0 / temperature)
	pred = pred / pred.norm(p=1, dim=dim, keepdim=True)
	return pred

# %%
def mixup(batch_1: Tensor, labels_1: Tensor, batch_2: Tensor, labels_2: Tensor) -> (Tensor, Tensor):
	lambda_ = np.random.beta(alpha, alpha)
	lambda_ = max(lambda_, 1.0 - lambda_)
	batch_mixed = batch_1 * lambda_ + batch_2 * (1.0 - lambda_)
	labels_mixed = labels_1 * lambda_ + labels_2 * (1.0 - lambda_)

	return batch_mixed, labels_mixed

# %%
def mixmatch(
	batch_s_augm: Tensor, batch_u_augm_multiple: Tensor, labels_s: Tensor, labels_u: Tensor
) -> (Tensor, Tensor, Tensor, Tensor):
	# Duplicate label u for all the augmented versions of batch u
	nb_augms = batch_u_augm_multiple.shape[0]
	repeated_size = [nb_augms] + [1] * (len(labels_u.size()) - 1)
	labels_u = labels_u.repeat(repeated_size)
	batch_u_augm = collapse_first_dimension(batch_u_augm_multiple)

	# Concatenate s and u in w
	batch_w = torch.cat((batch_s_augm, batch_u_augm))
	labels_w = torch.cat((labels_s, labels_u))

	# Shuffle batch and labels with the same order
	indices = torch.randperm(batch_w.shape[0])
	batch_w, labels_w = batch_w[indices], labels_w[indices]

	# Apply mixup with (s, w[:len(s)]) and with (u, w[len(s):])
	len_s = len(batch_s_augm)
	batch_s_mix, labels_s_mix = mixup(batch_s_augm, labels_s, batch_w[:len_s], labels_w[:len_s])
	batch_u_mix, labels_u_mix = mixup(batch_u_augm, labels_u, batch_w[len_s:], labels_w[len_s:])

	return batch_s_mix, batch_u_mix, labels_s_mix, labels_u_mix

# %%
def reset_metrics(metrics: Dict[str, Metrics]):
	for name, metric in metrics.items():
		metric.reset()

# %% [markdown]
# ## Training loop

# %%
def train(epoch: int):
	reset_metrics(metrics_train_s)
	reset_metrics(metrics_train_u)
	metrics_train_names = list(metrics_train_s.keys()) + list(metrics_train_u.keys()) + ["loss", "loss_s", "loss_u"]
	current_means = {"train/%s" % name: 0.0 for name in metrics_train_names}

	model.train()
	printer.print_header("train", metrics_train_names)

	for i, ((batch_s_augm, labels_s), batch_u_augm_multiple) in enumerate(loader_train):
		batch_s_augm = batch_s_augm.to(device).float()
		labels_s = labels_s.to(device).float()
		batch_u_augm_multiple = torch.stack(batch_u_augm_multiple).to(device).float()

		with torch.no_grad():
			# Guess label
			labels_u = guess_label(batch_u_augm_multiple, temperature, dim=1)

			# Apply mix
			batch_s_mix, batch_u_mix, labels_s_mix, labels_u_mix = mixmatch(
				batch_s_augm, batch_u_augm_multiple, labels_s, labels_u
			)

		# Compute logits
		logits_s_mix = model(batch_s_mix)
		logits_u_mix = model(batch_u_mix)

		pred_s_mix = activation(logits_s_mix, dim=1)
		pred_u_mix = activation(logits_u_mix, dim=1)

		# Update model
		loss, loss_s, loss_u = criterion(pred_s_mix, pred_u_mix, labels_s_mix, labels_u_mix, warmup.get_value())
		optim.zero_grad()
		loss.backward()
		optim.step()

		# Compute metrics
		with torch.no_grad():
			for name, metric in metrics_train_s.items():
				current_means["train/%s" % name] = metric(pred_s_mix, labels_s_mix)

			for name, metric in metrics_train_u.items():
				current_means["train/%s" % name] = metric(pred_u_mix, labels_u_mix)

			current_means.update({
				"train/loss": loss.item(),
				"train/loss_s": loss_s.item(),
				"train/loss_u": loss_u.item(),
			})

			printer.print_current_values(current_means, i, len(loader_train), epoch)
			warmup.step()

	for name, mean_ in current_means.items():
		writer.add_scalar(name, mean_, epoch)

	writer.add_scalar("hparams/lambda_u", warmup.get_value(), epoch)

# %% [markdown]
# ## Validation loop

# %%
def val(epoch: int):
	reset_metrics(metrics_val)
	current_means = {"val/%s" % name: 0.0 for name in metrics_val.keys()}

	model.eval()
	printer.print_header("val", metrics_val.keys(), False)

	for i, (x, y) in enumerate(loader_val):
		x = x.to(device).float()
		y = y.to(device).float()

		# Compute logits
		logits = model(x)
		pred = activation(logits, dim=1)

		for name, metric in metrics_val.items():
			current_means["val/{:s}".format(name)] = metric(pred, y)

		printer.print_current_values(current_means, i, len(loader_val), epoch)

	for name, mean_ in current_means.items():
		writer.add_scalar(name, mean_, epoch)

# %% [markdown]
# ## Start learning

# %%
for epoch in range(nb_epochs):
	train(epoch)
	with torch.no_grad():
		val(epoch)

writer.close()
# Out:
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   1 - 100% - 4.1326e-01 - 7.0674e-01 - 1.2355e+00 - 1.1637e+00 - 1.6034e+00 -   30.18    -
# -       val        -    acc     -  took (s)  -
# - Epoch   1 - 100% - 5.7514e-01 -    2.13    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   2 - 100% - 5.7118e-01 - 7.3028e-01 - 1.8668e+00 - 1.7084e+00 - 1.7656e+00 -   30.86    -
# -       val        -    acc     -  took (s)  -
# - Epoch   2 - 100% - 6.4480e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   3 - 100% - 6.4909e-01 - 7.4182e-01 - 1.9540e+00 - 1.8438e+00 - 8.1886e-01 -   29.62    -
# -       val        -    acc     -  took (s)  -
# - Epoch   3 - 100% - 6.6809e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   4 - 100% - 7.1142e-01 - 7.3878e-01 - 1.1789e+00 - 1.0221e+00 - 8.7361e-01 -   29.79    -
# -       val        -    acc     -  took (s)  -
# - Epoch   4 - 100% - 6.8650e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   5 - 100% - 7.5529e-01 - 7.5183e-01 - 9.7022e-01 - 5.9261e-01 - 1.6834e+00 -   29.90    -
# -       val        -    acc     -  took (s)  -
# - Epoch   5 - 100% - 6.9387e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   6 - 100% - 7.7424e-01 - 7.4669e-01 - 2.0771e+00 - 1.6557e+00 - 1.5655e+00 -   30.91    -
# -       val        -    acc     -  took (s)  -
# - Epoch   6 - 100% - 7.1248e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   7 - 100% - 7.8641e-01 - 7.5816e-01 - 8.0387e-01 - 6.2067e-01 - 5.8332e-01 -   30.00    -
# -       val        -    acc     -  took (s)  -
# - Epoch   7 - 100% - 7.1288e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   8 - 100% - 8.1119e-01 - 7.6375e-01 - 1.9374e+00 - 1.5081e+00 - 1.1959e+00 -   29.73    -
# -       val        -    acc     -  took (s)  -
# - Epoch   8 - 100% - 7.2801e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch   9 - 100% - 8.1385e-01 - 7.6396e-01 - 8.8156e-01 - 6.4291e-01 - 5.9098e-01 -   29.62    -
# -       val        -    acc     -  took (s)  -
# - Epoch   9 - 100% - 7.2422e-01 -    2.02    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  10 - 100% - 8.1818e-01 - 7.7025e-01 - 1.5560e+00 - 9.0269e-01 - 1.4560e+00 -   29.29    -
# -       val        -    acc     -  took (s)  -
# - Epoch  10 - 100% - 7.3676e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  11 - 100% - 8.2645e-01 - 7.7845e-01 - 1.8992e+00 - 1.5492e+00 - 7.0899e-01 -   29.26    -
# -       val        -    acc     -  took (s)  -
# - Epoch  11 - 100% - 7.5378e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  12 - 100% - 8.3537e-01 - 7.6485e-01 - 1.1437e+00 - 3.2308e-01 - 1.5241e+00 -   29.52    -
# -       val        -    acc     -  took (s)  -
# - Epoch  12 - 100% - 7.4373e-01 -    2.01    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  13 - 100% - 8.4173e-01 - 7.7651e-01 - 1.4542e+00 - 1.1136e+00 - 5.8391e-01 -   29.36    -
# -       val        -    acc     -  took (s)  -
# - Epoch  13 - 100% - 7.5975e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  14 - 100% - 8.4144e-01 - 7.8888e-01 - 2.3933e+00 - 1.6364e+00 - 1.2050e+00 -   29.55    -
# -       val        -    acc     -  took (s)  -
# - Epoch  14 - 100% - 7.5289e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  15 - 100% - 8.5348e-01 - 7.8034e-01 - 2.5155e+00 - 1.3940e+00 - 1.6662e+00 -   29.47    -
# -       val        -    acc     -  took (s)  -
# - Epoch  15 - 100% - 7.6344e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  16 - 100% - 8.5859e-01 - 7.9340e-01 - 1.5637e+00 - 5.5314e-01 - 1.4076e+00 -   29.75    -
# -       val        -    acc     -  took (s)  -
# - Epoch  16 - 100% - 7.5687e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  17 - 100% - 8.5966e-01 - 7.9649e-01 - 1.5306e+00 - 9.2175e-01 - 7.9821e-01 -   29.18    -
# -       val        -    acc     -  took (s)  -
# - Epoch  17 - 100% - 7.6403e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  18 - 100% - 8.6384e-01 - 7.8965e-01 - 1.6127e+00 - 4.3659e-01 - 1.4561e+00 -   30.03    -
# -       val        -    acc     -  took (s)  -
# - Epoch  18 - 100% - 7.6781e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  19 - 100% - 8.6701e-01 - 8.0513e-01 - 1.8141e+00 - 4.6216e-01 - 1.5858e+00 -   29.94    -
# -       val        -    acc     -  took (s)  -
# - Epoch  19 - 100% - 7.7787e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  20 - 100% - 8.6425e-01 - 8.1051e-01 - 1.5928e+00 - 1.1494e+00 - 4.9410e-01 -   29.69    -
# -       val        -    acc     -  took (s)  -
# - Epoch  20 - 100% - 7.7757e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  21 - 100% - 8.7156e-01 - 7.9507e-01 - 2.5705e+00 - 1.3479e+00 - 1.2974e+00 -   29.75    -
# -       val        -    acc     -  took (s)  -
# - Epoch  21 - 100% - 7.8324e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  22 - 100% - 8.6553e-01 - 8.0082e-01 - 1.9319e+00 - 2.7967e-01 - 1.6737e+00 -   29.38    -
# -       val        -    acc     -  took (s)  -
# - Epoch  22 - 100% - 7.8374e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  23 - 100% - 8.8051e-01 - 8.0388e-01 - 1.5532e+00 - 2.4753e-01 - 1.3057e+00 -   29.61    -
# -       val        -    acc     -  took (s)  -
# - Epoch  23 - 100% - 7.8334e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  24 - 100% - 8.7100e-01 - 8.0950e-01 - 1.6993e+00 - 1.0192e+00 - 6.8006e-01 -   30.15    -
# -       val        -    acc     -  took (s)  -
# - Epoch  24 - 100% - 7.8264e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  25 - 100% - 8.7158e-01 - 8.1183e-01 - 2.6308e+00 - 1.4559e+00 - 1.1750e+00 -   30.46    -
# -       val        -    acc     -  took (s)  -
# - Epoch  25 - 100% - 7.8981e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  26 - 100% - 8.7500e-01 - 8.0906e-01 - 1.5217e+00 - 1.0121e+00 - 5.0957e-01 -   30.32    -
# -       val        -    acc     -  took (s)  -
# - Epoch  26 - 100% - 7.7637e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  27 - 100% - 8.7655e-01 - 8.0920e-01 - 2.5542e+00 - 1.4254e+00 - 1.1287e+00 -   30.34    -
# -       val        -    acc     -  took (s)  -
# - Epoch  27 - 100% - 7.9558e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  28 - 100% - 8.7985e-01 - 8.0598e-01 - 6.4177e-01 - 3.2130e-01 - 3.2047e-01 -   30.51    -
# -       val        -    acc     -  took (s)  -
# - Epoch  28 - 100% - 7.9986e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  29 - 100% - 8.7879e-01 - 8.1600e-01 - 1.1152e+00 - 3.9500e-01 - 7.2017e-01 -   30.03    -
# -       val        -    acc     -  took (s)  -
# - Epoch  29 - 100% - 7.9787e-01 -    2.13    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  30 - 100% - 8.7959e-01 - 8.1976e-01 - 1.9973e+00 - 6.1669e-01 - 1.3806e+00 -   31.08    -
# -       val        -    acc     -  took (s)  -
# - Epoch  30 - 100% - 8.0305e-01 -    2.14    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  31 - 100% - 8.8323e-01 - 8.2112e-01 - 1.0297e+00 - 1.4708e-01 - 8.8262e-01 -   31.60    -
# -       val        -    acc     -  took (s)  -
# - Epoch  31 - 100% - 7.9678e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  32 - 100% - 8.8553e-01 - 8.2120e-01 - 2.2924e+00 - 1.0574e+00 - 1.2350e+00 -   31.41    -
# -       val        -    acc     -  took (s)  -
# - Epoch  32 - 100% - 7.9867e-01 -    2.16    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  33 - 100% - 8.8965e-01 - 8.1728e-01 - 2.4083e+00 - 9.0297e-01 - 1.5054e+00 -   31.56    -
# -       val        -    acc     -  took (s)  -
# - Epoch  33 - 100% - 7.9906e-01 -    2.12    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  34 - 100% - 8.8651e-01 - 8.1778e-01 - 6.1619e-01 - 1.6782e-01 - 4.4837e-01 -   31.75    -
# -       val        -    acc     -  took (s)  -
# - Epoch  34 - 100% - 8.0344e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  35 - 100% - 8.8305e-01 - 8.2696e-01 - 2.5554e+00 - 8.7849e-01 - 1.6769e+00 -   31.62    -
# -       val        -    acc     -  took (s)  -
# - Epoch  35 - 100% - 8.0394e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  36 - 100% - 8.9232e-01 - 8.2044e-01 - 1.1785e+00 - 9.3774e-01 - 2.4080e-01 -   30.40    -
# -       val        -    acc     -  took (s)  -
# - Epoch  36 - 100% - 8.1031e-01 -    2.15    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  37 - 100% - 8.9626e-01 - 8.2332e-01 - 8.6345e-01 - 5.2500e-01 - 3.3845e-01 -   30.71    -
# -       val        -    acc     -  took (s)  -
# - Epoch  37 - 100% - 8.0155e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  38 - 100% - 8.8601e-01 - 8.1317e-01 - 1.5160e+00 - 4.9131e-01 - 1.0247e+00 -   31.14    -
# -       val        -    acc     -  took (s)  -
# - Epoch  38 - 100% - 8.0613e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  39 - 100% - 8.8851e-01 - 8.2659e-01 - 2.7013e+00 - 1.2554e+00 - 1.4459e+00 -   30.75    -
# -       val        -    acc     -  took (s)  -
# - Epoch  39 - 100% - 8.0155e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  40 - 100% - 8.9437e-01 - 8.3078e-01 - 1.7874e+00 - 1.2386e+00 - 5.4880e-01 -   31.00    -
# -       val        -    acc     -  took (s)  -
# - Epoch  40 - 100% - 8.1141e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  41 - 100% - 8.9524e-01 - 8.2761e-01 - 2.8874e+00 - 1.4741e+00 - 1.4133e+00 -   31.08    -
# -       val        -    acc     -  took (s)  -
# - Epoch  41 - 100% - 8.0324e-01 -    2.13    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  42 - 100% - 8.9189e-01 - 8.2818e-01 - 1.7690e+00 - 1.2674e+00 - 5.0163e-01 -   30.85    -
# -       val        -    acc     -  took (s)  -
# - Epoch  42 - 100% - 8.0852e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  43 - 100% - 8.9704e-01 - 8.1666e-01 - 1.4634e+00 - 6.7698e-02 - 1.3957e+00 -   31.08    -
# -       val        -    acc     -  took (s)  -
# - Epoch  43 - 100% - 8.0523e-01 -    2.13    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  44 - 100% - 8.8421e-01 - 8.3501e-01 - 2.1302e+00 - 1.3306e+00 - 7.9961e-01 -   31.50    -
# -       val        -    acc     -  took (s)  -
# - Epoch  44 - 100% - 8.0852e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  45 - 100% - 8.9254e-01 - 8.3266e-01 - 2.7733e+00 - 1.3951e+00 - 1.3782e+00 -   30.82    -
# -       val        -    acc     -  took (s)  -
# - Epoch  45 - 100% - 8.1051e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  46 - 100% - 8.8869e-01 - 8.3166e-01 - 8.8889e-01 - 9.4108e-02 - 7.9478e-01 -   31.05    -
# -       val        -    acc     -  took (s)  -
# - Epoch  46 - 100% - 8.1240e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  47 - 100% - 8.9389e-01 - 8.3350e-01 - 1.4717e+00 - 1.0304e-01 - 1.3686e+00 -   31.30    -
# -       val        -    acc     -  took (s)  -
# - Epoch  47 - 100% - 8.1399e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  48 - 100% - 8.7996e-01 - 8.3260e-01 - 1.6544e+00 - 1.6911e-01 - 1.4853e+00 -   31.19    -
# -       val        -    acc     -  took (s)  -
# - Epoch  48 - 100% - 8.1150e-01 -    2.13    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  49 - 100% - 9.0085e-01 - 8.3111e-01 - 2.1870e+00 - 8.2425e-01 - 1.3627e+00 -   32.15    -
# -       val        -    acc     -  took (s)  -
# - Epoch  49 - 100% - 8.0593e-01 -    2.13    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  50 - 100% - 8.9363e-01 - 8.3493e-01 - 1.8458e+00 - 8.6815e-01 - 9.7766e-01 -   31.83    -
# -       val        -    acc     -  took (s)  -
# - Epoch  50 - 100% - 8.1270e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  51 - 100% - 8.9069e-01 - 8.2959e-01 - 4.9620e-01 - 7.0759e-02 - 4.2544e-01 -   31.62    -
# -       val        -    acc     -  took (s)  -
# - Epoch  51 - 100% - 8.1419e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  52 - 100% - 9.0721e-01 - 8.3324e-01 - 1.0585e+00 - 2.8550e-01 - 7.7296e-01 -   31.44    -
# -       val        -    acc     -  took (s)  -
# - Epoch  52 - 100% - 8.1369e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  53 - 100% - 8.8991e-01 - 8.4054e-01 - 2.1266e+00 - 1.0261e+00 - 1.1005e+00 -   31.02    -
# -       val        -    acc     -  took (s)  -
# - Epoch  53 - 100% - 8.1608e-01 -    2.18    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  54 - 100% - 8.8878e-01 - 8.3018e-01 - 1.9896e+00 - 1.3017e+00 - 6.8788e-01 -   30.73    -
# -       val        -    acc     -  took (s)  -
# - Epoch  54 - 100% - 8.1340e-01 -    2.15    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  55 - 100% - 9.0660e-01 - 8.3753e-01 - 8.3357e-01 - 6.0483e-02 - 7.7308e-01 -   31.28    -
# -       val        -    acc     -  took (s)  -
# - Epoch  55 - 100% - 8.2305e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  56 - 100% - 9.0503e-01 - 8.3619e-01 - 2.1844e+00 - 1.2603e+00 - 9.2411e-01 -   31.16    -
# -       val        -    acc     -  took (s)  -
# - Epoch  56 - 100% - 8.1937e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  57 - 100% - 8.9798e-01 - 8.3411e-01 - 1.2096e+00 - 4.5218e-01 - 7.5741e-01 -   31.18    -
# -       val        -    acc     -  took (s)  -
# - Epoch  57 - 100% - 8.1718e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  58 - 100% - 8.9358e-01 - 8.3303e-01 - 4.5423e-01 - 1.3623e-01 - 3.1800e-01 -   31.59    -
# -       val        -    acc     -  took (s)  -
# - Epoch  58 - 100% - 8.2096e-01 -    2.14    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  59 - 100% - 8.9256e-01 - 8.4324e-01 - 3.9186e-01 - 6.8683e-02 - 3.2318e-01 -   31.37    -
# -       val        -    acc     -  took (s)  -
# - Epoch  59 - 100% - 8.2255e-01 -    2.18    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  60 - 100% - 9.0599e-01 - 8.3595e-01 - 1.5944e+00 - 5.4553e-01 - 1.0488e+00 -   31.32    -
# -       val        -    acc     -  took (s)  -
# - Epoch  60 - 100% - 8.2355e-01 -    2.12    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  61 - 100% - 9.0196e-01 - 8.4272e-01 - 1.9437e+00 - 9.5627e-01 - 9.8743e-01 -   31.60    -
# -       val        -    acc     -  took (s)  -
# - Epoch  61 - 100% - 8.2006e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  62 - 100% - 9.0090e-01 - 8.3725e-01 - 1.6028e+00 - 8.6017e-01 - 7.4263e-01 -   31.81    -
# -       val        -    acc     -  took (s)  -
# - Epoch  62 - 100% - 8.2395e-01 -    2.25    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  63 - 100% - 8.9765e-01 - 8.3385e-01 - 2.6873e+00 - 1.4057e+00 - 1.2817e+00 -   31.99    -
# -       val        -    acc     -  took (s)  -
# - Epoch  63 - 100% - 8.2494e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  64 - 100% - 9.0542e-01 - 8.3622e-01 - 1.9059e+00 - 4.3616e-01 - 1.4698e+00 -   31.69    -
# -       val        -    acc     -  took (s)  -
# - Epoch  64 - 100% - 8.1668e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  65 - 100% - 8.9709e-01 - 8.3276e-01 - 1.7936e+00 - 1.3617e+00 - 4.3180e-01 -   31.95    -
# -       val        -    acc     -  took (s)  -
# - Epoch  65 - 100% - 8.2494e-01 -    2.21    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  66 - 100% - 9.0275e-01 - 8.4132e-01 - 1.3935e+00 - 7.6928e-01 - 6.2421e-01 -   31.72    -
# -       val        -    acc     -  took (s)  -
# - Epoch  66 - 100% - 8.2534e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  67 - 100% - 9.0525e-01 - 8.3866e-01 - 1.7138e+00 - 1.3024e+00 - 4.1138e-01 -   31.58    -
# -       val        -    acc     -  took (s)  -
# - Epoch  67 - 100% - 8.2793e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  68 - 100% - 9.0188e-01 - 8.3872e-01 - 4.9217e-01 - 1.1420e-01 - 3.7796e-01 -   31.58    -
# -       val        -    acc     -  took (s)  -
# - Epoch  68 - 100% - 8.2743e-01 -    2.12    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  69 - 100% - 8.9313e-01 - 8.3865e-01 - 1.6325e+00 - 2.5353e-01 - 1.3790e+00 -   31.55    -
# -       val        -    acc     -  took (s)  -
# - Epoch  69 - 100% - 8.2693e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  70 - 100% - 9.0771e-01 - 8.3779e-01 - 2.3710e+00 - 1.4915e+00 - 8.7945e-01 -   31.85    -
# -       val        -    acc     -  took (s)  -
# - Epoch  70 - 100% - 8.2723e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  71 - 100% - 8.9424e-01 - 8.4940e-01 - 2.4924e+00 - 1.3573e+00 - 1.1352e+00 -   31.61    -
# -       val        -    acc     -  took (s)  -
# - Epoch  71 - 100% - 8.2444e-01 -    2.16    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  72 - 100% - 8.9467e-01 - 8.4453e-01 - 2.2795e+00 - 1.1924e+00 - 1.0871e+00 -   31.79    -
# -       val        -    acc     -  took (s)  -
# - Epoch  72 - 100% - 8.2325e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  73 - 100% - 8.9628e-01 - 8.4137e-01 - 2.3399e+00 - 1.0486e+00 - 1.2912e+00 -   31.56    -
# -       val        -    acc     -  took (s)  -
# - Epoch  73 - 100% - 8.2325e-01 -    2.02    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  74 - 100% - 9.0564e-01 - 8.4377e-01 - 8.5312e-01 - 6.4518e-01 - 2.0794e-01 -   31.13    -
# -       val        -    acc     -  took (s)  -
# - Epoch  74 - 100% - 8.2743e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  75 - 100% - 8.9485e-01 - 8.5306e-01 - 1.1031e+00 - 8.4926e-01 - 2.5383e-01 -   31.25    -
# -       val        -    acc     -  took (s)  -
# - Epoch  75 - 100% - 8.2345e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  76 - 100% - 9.0212e-01 - 8.4593e-01 - 1.5160e+00 - 1.3682e+00 - 1.4775e-01 -   31.31    -
# -       val        -    acc     -  took (s)  -
# - Epoch  76 - 100% - 8.2753e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  77 - 100% - 9.0923e-01 - 8.4760e-01 - 1.7121e+00 - 1.3916e+00 - 3.2055e-01 -   31.47    -
# -       val        -    acc     -  took (s)  -
# - Epoch  77 - 100% - 8.2992e-01 -    2.15    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  78 - 100% - 8.9796e-01 - 8.4034e-01 - 1.3925e+00 - 4.0643e-02 - 1.3518e+00 -   31.95    -
# -       val        -    acc     -  took (s)  -
# - Epoch  78 - 100% - 8.2952e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  79 - 100% - 9.0507e-01 - 8.4706e-01 - 3.0649e+00 - 1.4592e+00 - 1.6057e+00 -   31.30    -
# -       val        -    acc     -  took (s)  -
# - Epoch  79 - 100% - 8.2613e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  80 - 100% - 9.0764e-01 - 8.4238e-01 - 2.1553e+00 - 7.1830e-01 - 1.4370e+00 -   31.94    -
# -       val        -    acc     -  took (s)  -
# - Epoch  80 - 100% - 8.2902e-01 -    2.12    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  81 - 100% - 8.9776e-01 - 8.5044e-01 - 8.6249e-01 - 9.3730e-02 - 7.6876e-01 -   31.06    -
# -       val        -    acc     -  took (s)  -
# - Epoch  81 - 100% - 8.2026e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  82 - 100% - 9.0564e-01 - 8.4317e-01 - 2.3204e+00 - 9.7634e-01 - 1.3441e+00 -   32.01    -
# -       val        -    acc     -  took (s)  -
# - Epoch  82 - 100% - 8.2544e-01 -    2.13    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  83 - 100% - 9.0590e-01 - 8.5372e-01 - 1.4873e+00 - 1.1043e+00 - 3.8295e-01 -   31.28    -
# -       val        -    acc     -  took (s)  -
# - Epoch  83 - 100% - 8.2564e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  84 - 100% - 9.0873e-01 - 8.4668e-01 - 1.6412e+00 - 2.8165e-01 - 1.3596e+00 -   30.82    -
# -       val        -    acc     -  took (s)  -
# - Epoch  84 - 100% - 8.3051e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  85 - 100% - 9.1191e-01 - 8.4331e-01 - 1.9418e+00 - 5.1847e-01 - 1.4233e+00 -   31.14    -
# -       val        -    acc     -  took (s)  -
# - Epoch  85 - 100% - 8.3012e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  86 - 100% - 9.0747e-01 - 8.5417e-01 - 2.6860e+00 - 1.2915e+00 - 1.3945e+00 -   31.61    -
# -       val        -    acc     -  took (s)  -
# - Epoch  86 - 100% - 8.2633e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  87 - 100% - 9.1350e-01 - 8.4339e-01 - 1.8275e+00 - 1.3238e+00 - 5.0373e-01 -   31.07    -
# -       val        -    acc     -  took (s)  -
# - Epoch  87 - 100% - 8.2992e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  88 - 100% - 8.9689e-01 - 8.4619e-01 - 1.3368e+00 - 1.0966e+00 - 2.4020e-01 -   30.83    -
# -       val        -    acc     -  took (s)  -
# - Epoch  88 - 100% - 8.2922e-01 -    2.12    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  89 - 100% - 9.1099e-01 - 8.4662e-01 - 1.3552e+00 - 4.3151e-02 - 1.3120e+00 -   31.28    -
# -       val        -    acc     -  took (s)  -
# - Epoch  89 - 100% - 8.2773e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  90 - 100% - 9.0921e-01 - 8.4710e-01 - 2.8229e+00 - 1.3830e+00 - 1.4399e+00 -   31.04    -
# -       val        -    acc     -  took (s)  -
# - Epoch  90 - 100% - 8.3280e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  91 - 100% - 9.0092e-01 - 8.4757e-01 - 2.5142e+00 - 1.0905e+00 - 1.4237e+00 -   31.01    -
# -       val        -    acc     -  took (s)  -
# - Epoch  91 - 100% - 8.3738e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  92 - 100% - 9.0323e-01 - 8.5179e-01 - 1.2477e+00 - 8.0141e-01 - 4.4625e-01 -   31.12    -
# -       val        -    acc     -  took (s)  -
# - Epoch  92 - 100% - 8.2594e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  93 - 100% - 9.0991e-01 - 8.4831e-01 - 3.6977e-01 - 1.2221e-01 - 2.4756e-01 -   31.02    -
# -       val        -    acc     -  took (s)  -
# - Epoch  93 - 100% - 8.2713e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  94 - 100% - 9.2220e-01 - 8.5256e-01 - 2.3095e+00 - 1.4185e+00 - 8.9101e-01 -   31.07    -
# -       val        -    acc     -  took (s)  -
# - Epoch  94 - 100% - 8.3021e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  95 - 100% - 9.1380e-01 - 8.4538e-01 - 1.7805e+00 - 1.3752e+00 - 4.0535e-01 -   31.13    -
# -       val        -    acc     -  took (s)  -
# - Epoch  95 - 100% - 8.2922e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  96 - 100% - 9.0346e-01 - 8.5788e-01 - 2.3959e+00 - 1.0361e+00 - 1.3598e+00 -   31.01    -
# -       val        -    acc     -  took (s)  -
# - Epoch  96 - 100% - 8.3758e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  97 - 100% - 9.1874e-01 - 8.5271e-01 - 1.1927e+00 - 5.6894e-02 - 1.1358e+00 -   31.30    -
# -       val        -    acc     -  took (s)  -
# - Epoch  97 - 100% - 8.2942e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  98 - 100% - 9.1535e-01 - 8.5515e-01 - 2.8067e+00 - 1.3080e+00 - 1.4987e+00 -   31.46    -
# -       val        -    acc     -  took (s)  -
# - Epoch  98 - 100% - 8.3678e-01 -    2.14    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch  99 - 100% - 9.1293e-01 - 8.6269e-01 - 8.7593e-01 - 5.1128e-02 - 8.2480e-01 -   31.37    -
# -       val        -    acc     -  took (s)  -
# - Epoch  99 - 100% - 8.3091e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 100 - 100% - 9.1550e-01 - 8.4952e-01 - 1.2247e+00 - 1.0730e+00 - 1.5171e-01 -   31.73    -
# -       val        -    acc     -  took (s)  -
# - Epoch 100 - 100% - 8.3708e-01 -    2.15    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 101 - 100% - 9.0129e-01 - 8.6594e-01 - 2.3494e+00 - 9.3520e-01 - 1.4142e+00 -   31.73    -
# -       val        -    acc     -  took (s)  -
# - Epoch 101 - 100% - 8.3280e-01 -    2.13    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 102 - 100% - 9.0640e-01 - 8.5046e-01 - 1.3409e+00 - 1.1774e+00 - 1.6355e-01 -   31.46    -
# -       val        -    acc     -  took (s)  -
# - Epoch 102 - 100% - 8.3459e-01 -    2.16    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 103 - 100% - 9.1123e-01 - 8.5396e-01 - 7.2524e-01 - 1.2995e-01 - 5.9529e-01 -   31.16    -
# -       val        -    acc     -  took (s)  -
# - Epoch 103 - 100% - 8.3619e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 104 - 100% - 9.0201e-01 - 8.4920e-01 - 2.7830e+00 - 1.4152e+00 - 1.3678e+00 -   30.43    -
# -       val        -    acc     -  took (s)  -
# - Epoch 104 - 100% - 8.3380e-01 -    2.12    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 105 - 100% - 9.0991e-01 - 8.5644e-01 - 1.6473e+00 - 9.0413e-01 - 7.4317e-01 -   30.29    -
# -       val        -    acc     -  took (s)  -
# - Epoch 105 - 100% - 8.2932e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 106 - 100% - 9.0447e-01 - 8.4767e-01 - 1.7444e+00 - 5.9109e-01 - 1.1533e+00 -   31.28    -
# -       val        -    acc     -  took (s)  -
# - Epoch 106 - 100% - 8.3609e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 107 - 100% - 9.1419e-01 - 8.4680e-01 - 1.9506e+00 - 6.2836e-01 - 1.3223e+00 -   31.45    -
# -       val        -    acc     -  took (s)  -
# - Epoch 107 - 100% - 8.3489e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 108 - 100% - 9.0882e-01 - 8.6028e-01 - 1.7135e+00 - 3.5366e-01 - 1.3598e+00 -   31.01    -
# -       val        -    acc     -  took (s)  -
# - Epoch 108 - 100% - 8.3002e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 109 - 100% - 9.1054e-01 - 8.5454e-01 - 2.3611e+00 - 1.1797e+00 - 1.1814e+00 -   30.68    -
# -       val        -    acc     -  took (s)  -
# - Epoch 109 - 100% - 8.3390e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 110 - 100% - 9.0721e-01 - 8.6013e-01 - 1.5518e+00 - 1.0512e-01 - 1.4466e+00 -   30.93    -
# -       val        -    acc     -  took (s)  -
# - Epoch 110 - 100% - 8.3708e-01 -    2.15    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 111 - 100% - 9.1384e-01 - 8.5776e-01 - 2.3615e+00 - 1.3028e+00 - 1.0588e+00 -   30.93    -
# -       val        -    acc     -  took (s)  -
# - Epoch 111 - 100% - 8.2852e-01 -    2.17    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 112 - 100% - 9.1206e-01 - 8.5874e-01 - 1.6210e+00 - 4.6173e-01 - 1.1593e+00 -   31.26    -
# -       val        -    acc     -  took (s)  -
# - Epoch 112 - 100% - 8.3798e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 113 - 100% - 9.1615e-01 - 8.5023e-01 - 2.5376e+00 - 1.2237e+00 - 1.3139e+00 -   31.31    -
# -       val        -    acc     -  took (s)  -
# - Epoch 113 - 100% - 8.3579e-01 -    2.12    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 114 - 100% - 9.1093e-01 - 8.5384e-01 - 1.7224e+00 - 1.2201e+00 - 5.0230e-01 -   31.59    -
# -       val        -    acc     -  took (s)  -
# - Epoch 114 - 100% - 8.3658e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 115 - 100% - 9.0481e-01 - 8.5362e-01 - 1.7974e+00 - 5.5280e-01 - 1.2446e+00 -   31.42    -
# -       val        -    acc     -  took (s)  -
# - Epoch 115 - 100% - 8.2633e-01 -    2.14    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 116 - 100% - 9.1047e-01 - 8.6275e-01 - 2.1766e+00 - 1.1717e+00 - 1.0049e+00 -   31.82    -
# -       val        -    acc     -  took (s)  -
# - Epoch 116 - 100% - 8.3449e-01 -    2.17    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 117 - 100% - 9.0882e-01 - 8.5783e-01 - 2.4144e+00 - 1.1305e+00 - 1.2839e+00 -   31.45    -
# -       val        -    acc     -  took (s)  -
# - Epoch 117 - 100% - 8.3041e-01 -    2.14    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 118 - 100% - 9.1021e-01 - 8.6149e-01 - 2.0876e+00 - 1.2364e+00 - 8.5127e-01 -   32.71    -
# -       val        -    acc     -  took (s)  -
# - Epoch 118 - 100% - 8.3390e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 119 - 100% - 9.1132e-01 - 8.6495e-01 - 1.2021e+00 - 5.8406e-02 - 1.1437e+00 -   31.60    -
# -       val        -    acc     -  took (s)  -
# - Epoch 119 - 100% - 8.3927e-01 -    2.15    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 120 - 100% - 9.0862e-01 - 8.5411e-01 - 1.9253e+00 - 5.7165e-01 - 1.3536e+00 -   30.54    -
# -       val        -    acc     -  took (s)  -
# - Epoch 120 - 100% - 8.3061e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 121 - 100% - 9.2042e-01 - 8.5751e-01 - 1.9976e+00 - 1.3382e+00 - 6.5944e-01 -   30.17    -
# -       val        -    acc     -  took (s)  -
# - Epoch 121 - 100% - 8.3818e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 122 - 100% - 9.1574e-01 - 8.5692e-01 - 1.1139e+00 - 6.1768e-01 - 4.9619e-01 -   30.01    -
# -       val        -    acc     -  took (s)  -
# - Epoch 122 - 100% - 8.4236e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 123 - 100% - 9.1611e-01 - 8.6208e-01 - 1.1828e+00 - 7.8429e-01 - 3.9854e-01 -   29.94    -
# -       val        -    acc     -  took (s)  -
# - Epoch 123 - 100% - 8.4206e-01 -    2.02    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 124 - 100% - 9.1620e-01 - 8.5622e-01 - 2.0986e+00 - 1.3398e+00 - 7.5883e-01 -   30.14    -
# -       val        -    acc     -  took (s)  -
# - Epoch 124 - 100% - 8.3609e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 125 - 100% - 9.1280e-01 - 8.5676e-01 - 1.2023e+00 - 6.1217e-01 - 5.9014e-01 -   30.03    -
# -       val        -    acc     -  took (s)  -
# - Epoch 125 - 100% - 8.3439e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 126 - 100% - 9.0773e-01 - 8.5753e-01 - 1.7287e+00 - 3.7714e-01 - 1.3515e+00 -   31.00    -
# -       val        -    acc     -  took (s)  -
# - Epoch 126 - 100% - 8.3290e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 127 - 100% - 9.1617e-01 - 8.6403e-01 - 1.8958e+00 - 9.8718e-01 - 9.0859e-01 -   29.98    -
# -       val        -    acc     -  took (s)  -
# - Epoch 127 - 100% - 8.3439e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 128 - 100% - 9.1232e-01 - 8.6080e-01 - 2.2116e+00 - 8.7908e-01 - 1.3325e+00 -   30.74    -
# -       val        -    acc     -  took (s)  -
# - Epoch 128 - 100% - 8.3310e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 129 - 100% - 9.0999e-01 - 8.6261e-01 - 1.6445e+00 - 1.0578e+00 - 5.8677e-01 -   30.24    -
# -       val        -    acc     -  took (s)  -
# - Epoch 129 - 100% - 8.3041e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 130 - 100% - 9.0893e-01 - 8.6078e-01 - 2.6436e+00 - 1.2488e+00 - 1.3948e+00 -   30.38    -
# -       val        -    acc     -  took (s)  -
# - Epoch 130 - 100% - 8.3529e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 131 - 100% - 9.1424e-01 - 8.5470e-01 - 1.4414e+00 - 1.2838e+00 - 1.5753e-01 -   30.24    -
# -       val        -    acc     -  took (s)  -
# - Epoch 131 - 100% - 8.3499e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 132 - 100% - 9.0845e-01 - 8.6083e-01 - 2.2465e+00 - 1.3081e+00 - 9.3841e-01 -   30.06    -
# -       val        -    acc     -  took (s)  -
# - Epoch 132 - 100% - 8.3519e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 133 - 100% - 9.1099e-01 - 8.6614e-01 - 1.1061e+00 - 8.4189e-01 - 2.6418e-01 -   30.00    -
# -       val        -    acc     -  took (s)  -
# - Epoch 133 - 100% - 8.4345e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 134 - 100% - 9.1472e-01 - 8.6659e-01 - 1.2748e+00 - 4.4602e-01 - 8.2882e-01 -   30.54    -
# -       val        -    acc     -  took (s)  -
# - Epoch 134 - 100% - 8.3897e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 135 - 100% - 9.1010e-01 - 8.6525e-01 - 2.6196e+00 - 1.2161e+00 - 1.4036e+00 -   30.38    -
# -       val        -    acc     -  took (s)  -
# - Epoch 135 - 100% - 8.3818e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 136 - 100% - 9.1256e-01 - 8.5790e-01 - 1.8490e+00 - 9.7096e-01 - 8.7799e-01 -   30.44    -
# -       val        -    acc     -  took (s)  -
# - Epoch 136 - 100% - 8.4076e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 137 - 100% - 9.1128e-01 - 8.5028e-01 - 9.3569e-01 - 2.4449e-02 - 9.1124e-01 -   30.39    -
# -       val        -    acc     -  took (s)  -
# - Epoch 137 - 100% - 8.4385e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 138 - 100% - 9.1339e-01 - 8.5920e-01 - 1.1693e+00 - 2.5833e-01 - 9.1100e-01 -   29.74    -
# -       val        -    acc     -  took (s)  -
# - Epoch 138 - 100% - 8.4126e-01 -    2.12    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 139 - 100% - 9.1811e-01 - 8.5904e-01 - 4.0849e-01 - 1.4435e-01 - 2.6414e-01 -   30.46    -
# -       val        -    acc     -  took (s)  -
# - Epoch 139 - 100% - 8.3489e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 140 - 100% - 9.1485e-01 - 8.5371e-01 - 9.6751e-01 - 4.5270e-01 - 5.1481e-01 -   29.96    -
# -       val        -    acc     -  took (s)  -
# - Epoch 140 - 100% - 8.4066e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 141 - 100% - 9.0096e-01 - 8.5733e-01 - 1.2690e+00 - 5.7678e-01 - 6.9227e-01 -   30.04    -
# -       val        -    acc     -  took (s)  -
# - Epoch 141 - 100% - 8.3987e-01 -    2.10    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 142 - 100% - 9.0793e-01 - 8.6132e-01 - 2.6973e+00 - 1.5112e+00 - 1.1861e+00 -   30.44    -
# -       val        -    acc     -  took (s)  -
# - Epoch 142 - 100% - 8.3748e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 143 - 100% - 9.0810e-01 - 8.6458e-01 - 1.0708e+00 - 9.3215e-01 - 1.3862e-01 -   30.28    -
# -       val        -    acc     -  took (s)  -
# - Epoch 143 - 100% - 8.3658e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 144 - 100% - 9.1171e-01 - 8.5896e-01 - 1.0723e+00 - 5.4973e-01 - 5.2256e-01 -   30.02    -
# -       val        -    acc     -  took (s)  -
# - Epoch 144 - 100% - 8.4504e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 145 - 100% - 9.1193e-01 - 8.6034e-01 - 1.2967e+00 - 4.7801e-02 - 1.2489e+00 -   30.31    -
# -       val        -    acc     -  took (s)  -
# - Epoch 145 - 100% - 8.3857e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 146 - 100% - 9.1765e-01 - 8.5847e-01 - 1.3640e+00 - 9.8025e-01 - 3.8379e-01 -   30.20    -
# -       val        -    acc     -  took (s)  -
# - Epoch 146 - 100% - 8.4126e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 147 - 100% - 9.1578e-01 - 8.5264e-01 - 2.6853e+00 - 1.3352e+00 - 1.3501e+00 -   30.45    -
# -       val        -    acc     -  took (s)  -
# - Epoch 147 - 100% - 8.4266e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 148 - 100% - 9.0375e-01 - 8.5580e-01 - 1.7342e+00 - 9.4476e-01 - 7.8942e-01 -   30.04    -
# -       val        -    acc     -  took (s)  -
# - Epoch 148 - 100% - 8.3818e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 149 - 100% - 9.1509e-01 - 8.6459e-01 - 1.4645e+00 - 2.4806e-01 - 1.2164e+00 -   30.11    -
# -       val        -    acc     -  took (s)  -
# - Epoch 149 - 100% - 8.3658e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 150 - 100% - 9.1587e-01 - 8.5286e-01 - 5.3465e-01 - 8.6217e-02 - 4.4843e-01 -   30.34    -
# -       val        -    acc     -  took (s)  -
# - Epoch 150 - 100% - 8.3967e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 151 - 100% - 9.1522e-01 - 8.5788e-01 - 2.6616e+00 - 1.3323e+00 - 1.3293e+00 -   30.42    -
# -       val        -    acc     -  took (s)  -
# - Epoch 151 - 100% - 8.4166e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 152 - 100% - 9.2577e-01 - 8.5549e-01 - 1.7222e+00 - 4.4550e-01 - 1.2768e+00 -   30.21    -
# -       val        -    acc     -  took (s)  -
# - Epoch 152 - 100% - 8.4385e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 153 - 100% - 9.1341e-01 - 8.6714e-01 - 1.4437e+00 - 2.3222e-01 - 1.2115e+00 -   31.17    -
# -       val        -    acc     -  took (s)  -
# - Epoch 153 - 100% - 8.4315e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 154 - 100% - 9.0723e-01 - 8.6821e-01 - 1.2026e+00 - 8.5274e-01 - 3.4987e-01 -   30.81    -
# -       val        -    acc     -  took (s)  -
# - Epoch 154 - 100% - 8.4435e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 155 - 100% - 9.1391e-01 - 8.6981e-01 - 2.3139e+00 - 1.2592e+00 - 1.0547e+00 -   30.48    -
# -       val        -    acc     -  took (s)  -
# - Epoch 155 - 100% - 8.4405e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 156 - 100% - 9.1606e-01 - 8.6562e-01 - 1.0225e+00 - 1.0660e-01 - 9.1588e-01 -   30.56    -
# -       val        -    acc     -  took (s)  -
# - Epoch 156 - 100% - 8.4285e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 157 - 100% - 9.1844e-01 - 8.6627e-01 - 1.8350e+00 - 7.7718e-01 - 1.0578e+00 -   30.50    -
# -       val        -    acc     -  took (s)  -
# - Epoch 157 - 100% - 8.3579e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 158 - 100% - 9.1358e-01 - 8.6187e-01 - 1.0034e+00 - 8.6333e-01 - 1.4010e-01 -   29.69    -
# -       val        -    acc     -  took (s)  -
# - Epoch 158 - 100% - 8.3748e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 159 - 100% - 9.1023e-01 - 8.5755e-01 - 1.5566e+00 - 1.9428e-01 - 1.3623e+00 -   30.02    -
# -       val        -    acc     -  took (s)  -
# - Epoch 159 - 100% - 8.3350e-01 -    2.01    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 160 - 100% - 9.0642e-01 - 8.6032e-01 - 1.9784e+00 - 1.2296e+00 - 7.4873e-01 -   30.06    -
# -       val        -    acc     -  took (s)  -
# - Epoch 160 - 100% - 8.3997e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 161 - 100% - 9.1402e-01 - 8.6241e-01 - 2.4389e+00 - 1.0469e+00 - 1.3920e+00 -   30.42    -
# -       val        -    acc     -  took (s)  -
# - Epoch 161 - 100% - 8.4455e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 162 - 100% - 9.2005e-01 - 8.6966e-01 - 1.8033e+00 - 3.4448e-01 - 1.4588e+00 -   29.97    -
# -       val        -    acc     -  took (s)  -
# - Epoch 162 - 100% - 8.4494e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 163 - 100% - 9.1043e-01 - 8.5747e-01 - 2.6061e+00 - 1.2343e+00 - 1.3718e+00 -   30.55    -
# -       val        -    acc     -  took (s)  -
# - Epoch 163 - 100% - 8.4096e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 164 - 100% - 9.1715e-01 - 8.6361e-01 - 1.4352e+00 - 5.7013e-01 - 8.6511e-01 -   30.40    -
# -       val        -    acc     -  took (s)  -
# - Epoch 164 - 100% - 8.4256e-01 -    2.02    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 165 - 100% - 9.1502e-01 - 8.6697e-01 - 2.0732e+00 - 1.3475e+00 - 7.2566e-01 -   30.20    -
# -       val        -    acc     -  took (s)  -
# - Epoch 165 - 100% - 8.4425e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 166 - 100% - 9.0695e-01 - 8.6385e-01 - 1.7565e+00 - 8.5359e-01 - 9.0294e-01 -   30.21    -
# -       val        -    acc     -  took (s)  -
# - Epoch 166 - 100% - 8.4285e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 167 - 100% - 9.1785e-01 - 8.5918e-01 - 1.0096e+00 - 7.9931e-01 - 2.1031e-01 -   30.34    -
# -       val        -    acc     -  took (s)  -
# - Epoch 167 - 100% - 8.4236e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 168 - 100% - 9.0906e-01 - 8.7056e-01 - 7.4370e-01 - 1.2410e-01 - 6.1960e-01 -   30.84    -
# -       val        -    acc     -  took (s)  -
# - Epoch 168 - 100% - 8.4285e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 169 - 100% - 9.1297e-01 - 8.6365e-01 - 7.2863e-01 - 3.4051e-01 - 3.8812e-01 -   30.03    -
# -       val        -    acc     -  took (s)  -
# - Epoch 169 - 100% - 8.3937e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 170 - 100% - 9.1302e-01 - 8.6787e-01 - 2.4500e+00 - 1.2344e+00 - 1.2156e+00 -   30.06    -
# -       val        -    acc     -  took (s)  -
# - Epoch 170 - 100% - 8.4843e-01 -    2.00    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 171 - 100% - 9.1367e-01 - 8.6681e-01 - 1.4098e+00 - 1.3963e-01 - 1.2702e+00 -   30.39    -
# -       val        -    acc     -  took (s)  -
# - Epoch 171 - 100% - 8.3987e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 172 - 100% - 9.1456e-01 - 8.6488e-01 - 2.1409e+00 - 1.3406e+00 - 8.0022e-01 -   30.32    -
# -       val        -    acc     -  took (s)  -
# - Epoch 172 - 100% - 8.4196e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 173 - 100% - 9.1894e-01 - 8.5930e-01 - 1.8153e+00 - 5.5500e-01 - 1.2603e+00 -   30.26    -
# -       val        -    acc     -  took (s)  -
# - Epoch 173 - 100% - 8.4146e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 174 - 100% - 9.1722e-01 - 8.6302e-01 - 2.2585e+00 - 9.4091e-01 - 1.3176e+00 -   30.64    -
# -       val        -    acc     -  took (s)  -
# - Epoch 174 - 100% - 8.3768e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 175 - 100% - 9.1456e-01 - 8.6744e-01 - 2.2406e+00 - 1.1277e+00 - 1.1129e+00 -   29.69    -
# -       val        -    acc     -  took (s)  -
# - Epoch 175 - 100% - 8.4335e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 176 - 100% - 9.0925e-01 - 8.6200e-01 - 1.7296e-01 - 2.9781e-02 - 1.4318e-01 -   29.80    -
# -       val        -    acc     -  took (s)  -
# - Epoch 176 - 100% - 8.4524e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 177 - 100% - 9.1465e-01 - 8.5667e-01 - 1.6234e+00 - 1.2899e+00 - 3.3350e-01 -   29.77    -
# -       val        -    acc     -  took (s)  -
# - Epoch 177 - 100% - 8.3977e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 178 - 100% - 9.2007e-01 - 8.6497e-01 - 2.2636e+00 - 1.1252e+00 - 1.1383e+00 -   30.41    -
# -       val        -    acc     -  took (s)  -
# - Epoch 178 - 100% - 8.3758e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 179 - 100% - 9.2216e-01 - 8.6793e-01 - 2.4784e+00 - 1.2488e+00 - 1.2296e+00 -   30.83    -
# -       val        -    acc     -  took (s)  -
# - Epoch 179 - 100% - 8.4226e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 180 - 100% - 9.2531e-01 - 8.6819e-01 - 2.2850e+00 - 1.1103e+00 - 1.1747e+00 -   30.56    -
# -       val        -    acc     -  took (s)  -
# - Epoch 180 - 100% - 8.4116e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 181 - 100% - 9.1657e-01 - 8.6761e-01 - 1.3007e+00 - 1.7811e-01 - 1.1226e+00 -   30.65    -
# -       val        -    acc     -  took (s)  -
# - Epoch 181 - 100% - 8.4853e-01 -    2.11    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 182 - 100% - 9.2074e-01 - 8.6547e-01 - 2.1841e+00 - 1.3341e+00 - 8.5000e-01 -   30.27    -
# -       val        -    acc     -  took (s)  -
# - Epoch 182 - 100% - 8.4295e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 183 - 100% - 9.2072e-01 - 8.6801e-01 - 7.8516e-01 - 6.4248e-01 - 1.4268e-01 -   30.29    -
# -       val        -    acc     -  took (s)  -
# - Epoch 183 - 100% - 8.4395e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 184 - 100% - 9.1308e-01 - 8.7460e-01 - 9.6898e-01 - 3.8356e-01 - 5.8542e-01 -   30.51    -
# -       val        -    acc     -  took (s)  -
# - Epoch 184 - 100% - 8.4325e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 185 - 100% - 9.2105e-01 - 8.7900e-01 - 1.1557e+00 - 1.0790e+00 - 7.6661e-02 -   30.71    -
# -       val        -    acc     -  took (s)  -
# - Epoch 185 - 100% - 8.4266e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 186 - 100% - 9.1411e-01 - 8.6431e-01 - 1.9437e+00 - 5.4321e-01 - 1.4005e+00 -   29.92    -
# -       val        -    acc     -  took (s)  -
# - Epoch 186 - 100% - 8.3997e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 187 - 100% - 9.2231e-01 - 8.7399e-01 - 1.2120e+00 - 4.3977e-01 - 7.7221e-01 -   30.19    -
# -       val        -    acc     -  took (s)  -
# - Epoch 187 - 100% - 8.4604e-01 -    2.03    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 188 - 100% - 9.2046e-01 - 8.7299e-01 - 1.2256e+00 - 8.8847e-01 - 3.3716e-01 -   30.45    -
# -       val        -    acc     -  took (s)  -
# - Epoch 188 - 100% - 8.4057e-01 -    2.06    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 189 - 100% - 9.2063e-01 - 8.7757e-01 - 7.1233e-01 - 2.2615e-02 - 6.8971e-01 -   30.74    -
# -       val        -    acc     -  took (s)  -
# - Epoch 189 - 100% - 8.4236e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 190 - 100% - 9.1324e-01 - 8.6798e-01 - 2.4173e+00 - 1.1525e+00 - 1.2648e+00 -   30.45    -
# -       val        -    acc     -  took (s)  -
# - Epoch 190 - 100% - 8.4365e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 191 - 100% - 9.1191e-01 - 8.7371e-01 - 1.8256e+00 - 1.0705e+00 - 7.5504e-01 -   30.49    -
# -       val        -    acc     -  took (s)  -
# - Epoch 191 - 100% - 8.4385e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 192 - 100% - 9.2614e-01 - 8.6279e-01 - 1.5743e+00 - 5.4340e-01 - 1.0309e+00 -   30.44    -
# -       val        -    acc     -  took (s)  -
# - Epoch 192 - 100% - 8.4126e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 193 - 100% - 9.1633e-01 - 8.6424e-01 - 1.5220e+00 - 1.7244e-01 - 1.3496e+00 -   30.55    -
# -       val        -    acc     -  took (s)  -
# - Epoch 193 - 100% - 8.4813e-01 -    2.08    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 194 - 100% - 9.0962e-01 - 8.6010e-01 - 2.2695e+00 - 1.0485e+00 - 1.2210e+00 -   29.96    -
# -       val        -    acc     -  took (s)  -
# - Epoch 194 - 100% - 8.4465e-01 -    2.05    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 195 - 100% - 9.2227e-01 - 8.6221e-01 - 1.8245e+00 - 4.2796e-01 - 1.3965e+00 -   29.94    -
# -       val        -    acc     -  took (s)  -
# - Epoch 195 - 100% - 8.4753e-01 -    2.01    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 196 - 100% - 9.1524e-01 - 8.6822e-01 - 1.6259e+00 - 7.4381e-01 - 8.8211e-01 -   30.73    -
# -       val        -    acc     -  took (s)  -
# - Epoch 196 - 100% - 8.3917e-01 -    2.07    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 197 - 100% - 9.2040e-01 - 8.6866e-01 - 1.3803e+00 - 1.7249e-01 - 1.2078e+00 -   30.20    -
# -       val        -    acc     -  took (s)  -
# - Epoch 197 - 100% - 8.3768e-01 -    2.09    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 198 - 100% - 9.1328e-01 - 8.7502e-01 - 2.2448e+00 - 1.1780e+00 - 1.0668e+00 -   30.60    -
# -       val        -    acc     -  took (s)  -
# - Epoch 198 - 100% - 8.4236e-01 -    2.04    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 199 - 100% - 9.1400e-01 - 8.6754e-01 - 1.1567e+00 - 7.1362e-01 - 4.4305e-01 -   30.30    -
# -       val        -    acc     -  took (s)  -
# - Epoch 199 - 100% - 8.4226e-01 -    2.01    -
#
# -      train       -   acc_s    -   acc_u    -    loss    -   loss_s   -   loss_u   -  took (s)  -
# - Epoch 200 - 100% - 9.2427e-01 - 8.6684e-01 - 2.5171e+00 - 1.2240e+00 - 1.2931e+00 -   30.57    -
# -       val        -    acc     -  took (s)  -
# - Epoch 200 - 100% - 8.4047e-01 -    2.07    -
